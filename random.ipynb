# %%
import matplotlib.pyplot as plt

# %%
import pathlib

# %%
from generfaker.rnd_matrix import *
from generfaker.rnd_record import *

# %% [markdown]
# ## Generate Random 2D-Matrix

# %%
rnd_replace_with_const(10, 3, 1)
# Out:
# array([[1.        , 0.22197869, 0.34687587],
#        [1.        , 0.45968881, 0.67549605],
#        [1.        , 0.60005303, 0.70439525],
#        [1.        , 0.69198681, 0.74282641],
#        [1.        , 0.79160855, 0.9874559 ],
#        [1.        , 0.28362533, 0.76079874],
#        [1.        , 0.42805987, 0.96714913],
#        [1.        , 0.38374631, 0.7045656 ],
#        [1.        , 0.64056134, 0.7385493 ],
#        [1.        , 0.24988863, 0.76119488]])

# %%
rnd_matrix = rnd_replace_with_const(3, 10, 0, 0)
rnd_matrix
# Out:
# array([[0.        , 0.25321849, 0.30522623, 0.44899486, 0.47953147,
#         0.56043565, 0.65792716, 0.77251542, 0.77810945, 0.89593729],
#        [0.        , 0.12965807, 0.26564186, 0.39459674, 0.46515639,
#         0.50191091, 0.54681745, 0.90708414, 0.96723299, 0.98635582],
#        [0.        , 0.09939104, 0.17525553, 0.20560583, 0.30568979,
#         0.39412692, 0.43565897, 0.53085594, 0.71077363, 0.9154377 ]])

# %%
_, ax = plt.subplots(figsize=(6, 4))

for i in range(rnd_matrix.shape[0]):
    ax.plot(range(rnd_matrix.shape[1]), rnd_matrix[i,:])

# %%
files = pathlib.Path("probability")

for file in files.rglob(pattern="*.ipynb"):
    file.rename(file.name.lower())
